# %%
import requests
from bs4 import BeautifulSoup

# %%
web_site = requests.get('https://www.naver.com/')
bs = BeautifulSoup(web_site.content , 'html.parser')

# %%
print(bs)
# Out:
# <!DOCTYPE html>
# ...

# %%
all_divs = bs.find_all('div')
print(all_divs)
# Out:
# [<div id="u_skip"> <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a> <a href="#themecast"><span>주제별캐스트 바로가기</span></a> <a href="#timesquare"><span>타임스퀘어 바로가기</span></a> <a href="#shopcast"><span>쇼핑캐스트 바로가기</span></a> <a href="#account"><span>로그인 바로가기</span></a> </div>, <div id="wrap"> <style type="text/css">._1hiMWemA{background-color:#fff1c0;height:49px}._1hiMWemA ._31YyaJjU,._1hiMWemA .uSvV2qR8,._1hiMWemA a{height:49px}._1hiMWemA p span,._1hiMWemA p strong{line-height:49px}._1hiMWemA ._31YyaJjU span:before,._1hiMWemA .uSvV2qR8:after,._1hiMWemA i,._1hiMWemA p:before{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/ico@2x.png);background-repeat:no-repeat;background-size:98px 47px}[data-useragent*="MSIE 8"] ._1hiMWemA ._31YyaJjU span:before,[data-useragent*="MSIE 8"] ._1hiMWemA .uSvV2qR8:after,[data-useragent*="MSIE 8"] ._1hiMWemA i,[data-useragent*="MSIE 8"] ._1hiMWemA p:before{background-image:url(https://static-whale.pstat
# ...

# %%
first_div = bs.find('div')
print(first_div)
# Out:
# <div id="u_skip"> <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a> <a href="#themecast"><span>주제별캐스트 바로가기</span></a> <a href="#timesquare"><span>타임스퀘어 바로가기</span></a> <a href="#shopcast"><span>쇼핑캐스트 바로가기</span></a> <a href="#account"><span>로그인 바로가기</span></a> </div>

# %%
div_id = bs.find('div', {'id' : 'gnb'})
print(div_id)
# Out:
# <div id="gnb">
# <div class="gnb_inner" id="NM_FAVORITE">
# <div class="group_nav">
# <ul class="list_nav type_fix">
# <li class="nav_item">
# <a class="nav" data-clk="svc.mail" href="https://mail.naver.com/"><i class="ico_mail"></i>메일</a>
# </li>
# <li class="nav_item"><a class="nav" data-clk="svc.cafe" href="https://section.cafe.naver.com/">카페</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.blog" href="https://section.blog.naver.com/">블로그</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.kin" href="https://kin.naver.com/">지식iN</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.shopping" href="https://shopping.naver.com/">쇼핑</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.pay" href="https://order.pay.naver.com/home">Pay</a></li>
# <li class="nav_item">
# <a class="nav" data-clk="svc.tvcast" href="https://tv.naver.com/"><i class="ico_tv"></i>TV</a>
# </li>
# </ul>
# <ul class="list_nav NM_FAVORITE_LIST">
# ...

# %%
# 네이버 실검은 json(java script object notation) file로 읽어와서 보여주므로 실검 json파일 원본을 읽어서 data만 출력한다. 

json = requests.get('https://www.naver.com/srchrank?frm=main').json()
ranks = json.get('data')

print(ranks)
# Out:
# [{'rank': 1, 'keyword': '개기일식', 'keyword_synonyms': []}, {'rank': 2, 'keyword': '부분일식 보는법', 'keyword_synonyms': []}, {'rank': 3, 'keyword': '일식 시간', 'keyword_synonyms': []}, {'rank': 4, 'keyword': '부분일식 생중계', 'keyword_synonyms': []}, {'rank': 5, 'keyword': '일식 생중계', 'keyword_synonyms': []}, {'rank': 6, 'keyword': '월식', 'keyword_synonyms': ['부분일식 촬영']}, {'rank': 7, 'keyword': '개기일식 시간', 'keyword_synonyms': []}, {'rank': 8, 'keyword': '개기월식', 'keyword_synonyms': []}, {'rank': 9, 'keyword': '부분일식 시간', 'keyword_synonyms': []}, {'rank': 10, 'keyword': '개기일식 셀로판지', 'keyword_synonyms': ['부분일식 선글라스', '개기일식 선글라스', '일식 셀로판지', '일식 선글라스']}, {'rank': 11, 'keyword': '조명섭', 'keyword_synonyms': ['조명섭 고향']}, {'rank': 12, 'keyword': '하지', 'keyword_synonyms': []}, {'rank': 13, 'keyword': '셀로판지', 'keyword_synonyms': []}, {'rank': 14, 'keyword': '개기일식 안경', 'keyword_synonyms': []}, {'rank': 15, 'keyword': '부분일식 안경', 'keyword_synonyms': []}, {'rank': 16, 'keyword': '문성훈 냉동삼겹살', 'keyword_synonyms': []}, {'r
# ...

# %%
for r in ranks:
    # 각 데이터는 rank, keyword, keyword_synomyms
    rank = r.get("rank")
    keyword = r.get("keyword")
    keyword_synonyms = r.get("keyword_synonyms")
    print(rank, keyword,'동의어: ' +  str(keyword_synonyms))
# Out:
# 1 개기일식 동의어: []
# 2 부분일식 보는법 동의어: []
# 3 일식 시간 동의어: []
# 4 부분일식 생중계 동의어: []
# 5 일식 생중계 동의어: []
# 6 월식 동의어: ['부분일식 촬영']
# 7 개기일식 시간 동의어: []
# 8 개기월식 동의어: []
# 9 부분일식 시간 동의어: []
# 10 개기일식 셀로판지 동의어: ['부분일식 선글라스', '개기일식 선글라스', '일식 셀로판지', '일식 선글라스']
# 11 조명섭 동의어: ['조명섭 고향']
# 12 하지 동의어: []
# 13 셀로판지 동의어: []
# 14 개기일식 안경 동의어: []
# 15 부분일식 안경 동의어: []
# 16 문성훈 냉동삼겹살 동의어: []
# 17 크러쉬 동의어: []
# 18 유소연 동의어: []
# 19 사이코지만 괜찮아 동의어: []
# 20 온리 더 브레이브 동의어: []

# %%
# .json()으로 읽지 않고 데이터를 읽기를 시도.

read_test = requests.get('https://www.naver.com/srchrank?frm=main')
ranks_test = BeautifulSoup(read_test.content , 'html.parser')

print(ranks_test)
# Out:
# {"ts":"2020-06-21T17:18:00+0900","sm":"agallgrpmamsi0en0sp0","rop":[{"ag":"all"},{"gr":"01"},{"ma":"-2"},{"si":"00"},{"en":"00"},{"sp":"00"}],"data":[{"rank":1,"keyword":"개기일식","keyword_synonyms":[]},{"rank":2,"keyword":"부분일식 보는법","keyword_synonyms":[]},{"rank":3,"keyword":"일식 시간","keyword_synonyms":[]},{"rank":4,"keyword":"부분일식 생중계","keyword_synonyms":[]},{"rank":5,"keyword":"일식 생중계","keyword_synonyms":[]},{"rank":6,"keyword":"월식","keyword_synonyms":["부분일식 촬영"]},{"rank":7,"keyword":"개기일식 시간","keyword_synonyms":[]},{"rank":8,"keyword":"개기월식","keyword_synonyms":[]},{"rank":9,"keyword":"부분일식 시간","keyword_synonyms":[]},{"rank":10,"keyword":"개기일식 셀로판지","keyword_synonyms":["부분일식 선글라스","개기일식 선글라스","일식 셀로판지","일식 선글라스"]},{"rank":11,"keyword":"조명섭","keyword_synonyms":["조명섭 고향"]},{"rank":12,"keyword":"하지","keyword_synonyms":[]},{"rank":13,"keyword":"셀로판지","keyword_synonyms":[]},{"rank":14,"keyword":"개기일식 안경","keyword_synonyms":[]},{"rank":15,"keyword":"부분일식 안경","keyword_synonyms":[]},{"rank":1
# ...

# %%
# data를 읽을 때 ranks_test에 있는 content에서 data를 뽑아도 None값이 나온다.

ranks_data = ranks_test.get("data")
print(ranks_data)
# Out:
# None

# %%
# find로 읽기 시도를 했으나, data는 tag가 아니라 읽을 수 없음. => .json() 으로 읽자.

ranks_data = ranks_test.find('data')
print(ranks_data)
# Out:
# None
